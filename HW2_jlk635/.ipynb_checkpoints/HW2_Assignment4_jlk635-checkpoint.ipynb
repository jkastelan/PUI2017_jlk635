# %%
from __future__ import division, print_function
__author__ = 'fbb CUSP 2016'
import os
import numpy as np
from numpy.random import randn
import pylab as pl

from pandas import Series, DataFrame
import pandas
import pandas as pd

PUIdata = os.getenv("PUIDATA")

# %%
# use the environmental variable PUIDATA to access data 
# stored in your own PUIDATA directory
PUIdata = os.getenv('PUIDATA')

print(PUIdata)
# Out:
# /home/cusp/jlk635/PUIdata

# %%
SchoolBusBreakdowns = pd.read_csv(os.getenv('DFDATA') + "/ez4e-fazm/1479192684/ez4e-fazm.csv")

# %%
SchoolBusBreakdowns[:5]
# Out:
#   School_Year  Busbreakdown_ID           Run_Type  Bus_No Route_Number  \
# 0   2015-2016          1220252  Special Ed AM Run     104         K638
# 1   2015-2016          1222207  Special Ed AM Run  GT1473         Y888
# 2   2015-2016          1222301  Special Ed AM Run    2714         M572
# 3   2015-2016          1226511  Special Ed PM Run    9032         K191
# 4   2015-2016          1227241           Pre-K/EI    9815            3
#
#                Reason Schools_Serviced             Occurred_On  \
# 0  Mechanical Problem            22001  10/08/2015 07:00:00 AM
# 1       Heavy Traffic            07697  10/16/2015 07:13:00 AM
# 2       Heavy Traffic            02001  10/16/2015 07:22:00 AM
# 3       Heavy Traffic            32299  10/30/2015 12:56:00 PM
# 4       Heavy Traffic             C329  11/04/2015 08:46:00 AM
#
#                Created_On       Boro        ...         How_Long_Delayed  \
# 0  10/08/2015 07:21:00 AM   Brooklyn        ...                      NaN
# ...

# %%
#drop variables you do not need
SchoolBusBreakdownsTrim = SchoolBusBreakdowns[['Occurred_On','Number_Of_Students_On_The_Bus']]

# %%
pd.to_datetime(SchoolBusBreakdownsTrim['Occurred_On']).head()
# Out:
# 0   2015-10-08 07:00:00
# 1   2015-10-16 07:13:00
# 2   2015-10-16 07:22:00
# 3   2015-10-30 12:56:00
# 4   2015-11-04 08:46:00
# Name: Occurred_On, dtype: datetime64[ns]

# %%
SchoolBusBreakdownsTrim['Occurred_On'] = pd.to_datetime(SchoolBusBreakdownsTrim['Occurred_On'])

# %%
SchoolBusBreakdownsTrim
# Out:
#               Occurred_On  Number_Of_Students_On_The_Bus
# 0     2015-10-08 07:00:00                              0
# 1     2015-10-16 07:13:00                              6
# 2     2015-10-16 07:22:00                              4
# 3     2015-10-30 12:56:00                              0
# 4     2015-11-04 08:46:00                             16
# 5     2015-11-24 07:29:00                              4
# 6     2015-12-01 14:42:00                              0
# 7     2015-12-02 07:59:00                             16
# 8     2015-12-14 07:57:00                              1
# 9     2015-12-15 15:25:00                             21
# 10    2015-09-29 08:28:00                              2
# 11    2015-11-24 07:49:00                              3
# 12    2015-11-25 07:20:00                              2
# 13    2015-12-01 14:39:00                              0
# 14    2015-12-03 07:30:00                              0
# ...

# %%
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 


SchoolBusBreakdownsTrim.plot(x='Occurred_On', y='Number_Of_Students_On_The_Bus', style='.', figsize=(15,8), c='limegreen' )

plt.title('No. of students on broken down buses over time', fontsize=14)
plt.xlabel('Time', fontsize=12)
plt.ylabel('No. of students', fontsize=12)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Figure 2:
# The time-series plots timing of broken down buses (school buses), and the number of students who were stranded on the bus when it broke down.
